# %% [markdown]
# # Portfolio optimization
#
# The goal of this notebook is: given a portfolio containing certain component stocks, which is the best combination that maximize return while minimizing volitility

# %% [markdown]
# ## Import data

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/dangminh.nguyen/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
assets = ['ARKW','VDC']
df = pd.DataFrame()
for a in assets:
    df[a] = wb.DataReader(a,data_source='yahoo',start='2015-01-01')['Adj Close']

# %%
df.head()
# Out:
#                  ARKW         VDC
# Date
# 2014-12-31  17.378334  109.732887
# 2015-01-02  17.200571  109.067001
# 2015-01-05  16.938162  108.173294
# 2015-01-06  16.789179  108.085686
# 2015-01-07  16.958477  109.864319

# %%
(df/df.iloc[0]).plot(figsize=(10,5))

# %%
df_ret = df/df.shift(1)-1
df_ret.mean()*250
# Out:
# ARKW    0.266488
# VDC     0.071546
# dtype: float64

# %%
df_ret.cov()*250
# Out:
#           ARKW       VDC
# ARKW  0.072408  0.020750
# VDC   0.020750  0.024616

# %%
df_ret.corr()
# Out:
#           ARKW       VDC
# ARKW  1.000000  0.491483
# VDC   0.491483  1.000000

# %% [markdown]
# ## Efficient frontier

# %%
asset_ret = []
asset_volatile = []
w_range = np.arange(0,1.0,0.001)
for w in w_range:
    weights = np.array([w,1-w])
    asset_ret.append(np.sum(weights*df_ret.mean())*250)
    asset_volatile.append(np.sqrt(np.dot(weights.T, np.dot(df_ret.cov()*250,weights))))

# %%
df_portfolio = pd.DataFrame()
df_portfolio['w'] = w_range
df_portfolio['return'] = asset_ret
df_portfolio['volatility'] = asset_volatile

# %%
df_portfolio.head()
# Out:
#        w    return  volatility
# 0  0.000  0.071546    0.156895
# 1  0.001  0.071741    0.156870
# 2  0.002  0.071936    0.156846
# 3  0.003  0.072131    0.156823
# 4  0.004  0.072326    0.156799

# %%
df_portfolio.plot.scatter(x='volatility',y='return',c='w',
                         colormap='gist_rainbow',
                         figsize=(10,6))
